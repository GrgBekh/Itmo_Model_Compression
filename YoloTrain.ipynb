# %%
# !pip install -q \
autodistill \
autodistill-yolov8 \
roboflow \
supervision==0.9.0

# %%
import supervision as sv
from tqdm.notebook import tqdm
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from ultralytics import YOLO
from roboflow import Roboflow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
rf = Roboflow(api_key="KPdQzbniHwGMSQyhZx76")
project = rf.workspace("surfacedefectdetectiondataset").project("animal-mflmf")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.81, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to animal-1 in yolov8:: 100%|██████████| 1536/1536 [00:00<00:00, 4644.25it/s]

# %%
IMAGE_DIR_PATH = "/content/animal-1/train/images"
DATA_YAML_PATH = "/content/animal-1/data.yaml"

# %%
# !cp -r /content/drive/MyDrive/cat_dog_dataset/ /content/animal-1/train/

# %%
target_model = YOLO("yolov8l.pt")

# %%
target_model.train(data = DATA_YAML_PATH, epochs=5, batch = 8, pretrained = True)
# Out:
# New https://pypi.org/project/ultralytics/8.0.199 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import time
import torch

inp = torch.randn(1, 3, 224, 224)

num_samples = 100
start_time = time.time()
for _ in tqdm(range(num_samples)):
    output = target_model(inp / 255)
end_time = time.time()

infer_time = ((end_time - start_time) / num_samples) * 1000
print(f'Avg inference time: {infer_time:.4f} ms')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 77.1ms
#
# 21.2ms
#
# 19.2ms
#
# 19.4ms
#
# 18.5ms
#
# 16.6ms
#
# 18.4ms
#
# 18.1ms
#
# 17.8ms
#
# 16.9ms
#
# 16.3ms
#
# 20.6ms
#
# 17.9ms
#
# 16.1ms
#
# 10.9ms
#
# 12.8ms
#
# 14.4ms
#
# 11.6ms
#
# 11.4ms
#
# 11.3ms
#
# 12.9ms
#
# 11.8ms
#
# 11.5ms
#
# 21.1ms
#
# 11.8ms
#
# 11.5ms
#
# 12.3ms
#
# 10.7ms
#
# 9.8ms
#
# 13.9ms
#
# 8.8ms
#
# 9.8ms
#
# 9.1ms
#
# 9.3ms
#
# 10.8ms
#
# 10.2ms
#
# 17.9ms
#
# 16.4ms
#
# 13.6ms
#
# 11.6ms
#
# 9.8ms
#
# 9.9ms
#
# 15.2ms
#
# 10.8ms
#
# 11.2ms
#
# 10.3ms
#
# 10.2ms
#
# 10.4ms
#
# 9.6ms
#
# 15.8ms
#
# 13.4ms
#
# 9.8ms
#
# 12.1ms
#
# 10.2ms
#
# 10.0ms
#
# 16.8ms
#
# 11.5ms
#
# 10.3ms
#
# 13.5ms
#
# 12.1ms
#
# 10.0ms
#
# 13.6ms
#
# 9.8ms
#
# 11.3ms
#
# 9.7ms
#
# 10.5ms
#
# 10.5ms
#
# 11.5ms
#
# 12.4ms
#
# 9.2ms
#
# 10.2ms
#
# 10.2ms
#
# 12.9ms
#
# 11.9ms
#
# 10.6ms
#
# 11.8ms
#
# 10.5ms
#
# 11.7ms
#
# 9.7ms
#
# 10.8ms
#
# 11.1ms
#
# 16.4ms
#
# 12.1ms
#
# 9.8ms
#
# 11.9ms
#
# 10.1ms
#
# 13.1ms
#
# 11.1ms
#
# ...
